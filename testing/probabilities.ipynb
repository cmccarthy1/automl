# %%
\l ../automl.q
.aml.loadfile`:init.q

# %%
n:1000
x:flip(n?1f;n?2f;n?50;asc n?100)
y:asc n?0b
d:.ml.traintestsplit[x;y;.2]

# %%
rfc:.p.import[`sklearn.ensemble][`:RandomForestClassifier][]
rfc[`:fit]. value 2#d;
p:rfc[`:predict_proba][d`xtest]`
# Out:
# /home/deanna/.local/lib/python3.6/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
show flip cg:.aml.i.cumulative_gain_curve[d`ytest;p]
# Out:
# pc  | 0                                                                      ..
# gain| 0 0.009803922 0.01960784 0.02941176 0.03921569 0.04901961 0.05882353 0...
# pcnt| 0 0.005 0.01 0.015 0.02 0.025 0.03 0.035 0.04 0.045 0.05 0.055 0.06 0.0..

# %%
.aml.i.gainliftplt[cg;`lift]

# %%
.aml.i.gainliftplt[cg;`gain]

# %% [markdown]
# ---
